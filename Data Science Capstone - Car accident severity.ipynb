# %%
#Import Libraries

import pandas as pd 
import numpy as np
import os

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Reference Number  Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles  \
# 0          58F1730             436147              434957                   2
# 1          58F1730             436147              434957                   2
# 2          58F1730             436147              434957                   2
# 3          58F1730             436147              434957                   2
# 4          58F1730             436147              434957                   2
#
#   Accident Date  Time (24hr)  1st Road Class 1st Road Class & No  \
# 0    15/08/2019         1812               3               A6120
# 1    15/08/2019         1812               3               A6120
# 2    15/08/2019         1812               3               A6120
# 3    15/08/2019         1812               3               A6120
# 4    15/08/2019         1812               3               A6120
#
#    Road Surface  Lighting Conditions  Weather Conditions Local Authority  \
# ...

# %%
df_data_1.head()
# Out:
#   Reference Number  Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles  \
# 0          58F1730             436147              434957                   2
# 1          58F1730             436147              434957                   2
# 2          58F1730             436147              434957                   2
# 3          58F1730             436147              434957                   2
# 4          58F1730             436147              434957                   2
#
#   Accident Date  Time (24hr)  1st Road Class 1st Road Class & No  \
# 0    15/08/2019         1812               3               A6120
# 1    15/08/2019         1812               3               A6120
# 2    15/08/2019         1812               3               A6120
# 3    15/08/2019         1812               3               A6120
# 4    15/08/2019         1812               3               A6120
#
#    Road Surface  Lighting Conditions  Weather Conditions Local Authority  \
# ...

# %%
df_data_1.describe()
# Out:
#        Grid Ref: Easting  Grid Ref: Northing  Number of Vehicles  Time (24hr)  \
# count        1907.000000         1907.000000         1907.000000  1907.000000
# mean       430273.604615       434036.861563            1.969061  1385.495018
# std          5153.916990         4852.561221            0.819226   517.021399
# min        414747.000000       423157.000000            1.000000     0.000000
# 25%        427396.000000       431197.500000            2.000000  1000.000000
# 50%        430096.000000       433982.000000            2.000000  1500.000000
# 75%        432241.000000       435947.000000            2.000000  1756.000000
# max        445481.000000       449599.000000            6.000000  2355.000000
#
#        1st Road Class  Road Surface  Lighting Conditions  Weather Conditions  \
# count     1907.000000   1907.000000          1907.000000         1907.000000
# mean         4.399580      1.321972             1.911904            1.241741
# ...

# %%
df_data_1.dtypes
# Out:
# Reference Number       object
# Grid Ref: Easting       int64
# Grid Ref: Northing      int64
# Number of Vehicles      int64
# Accident Date          object
# Time (24hr)             int64
# 1st Road Class          int64
# 1st Road Class & No    object
# Road Surface            int64
# Lighting Conditions     int64
# Weather Conditions      int64
# Local Authority        object
# Vehicle Number          int64
# Type of Vehicle         int64
# Casualty Class          int64
# Casualty Severity       int64
# Sex of Casualty         int64
# Age of Casualty         int64
# dtype: object

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1907 entries, 0 to 1906
# Data columns (total 18 columns):
# Reference Number       1907 non-null object
# Grid Ref: Easting      1907 non-null int64
# Grid Ref: Northing     1907 non-null int64
# Number of Vehicles     1907 non-null int64
# Accident Date          1907 non-null object
# Time (24hr)            1907 non-null int64
# 1st Road Class         1907 non-null int64
# 1st Road Class & No    1907 non-null object
# Road Surface           1907 non-null int64
# Lighting Conditions    1907 non-null int64
# Weather Conditions     1907 non-null int64
# Local Authority        1907 non-null object
# Vehicle Number         1907 non-null int64
# Type of Vehicle        1907 non-null int64
# Casualty Class         1907 non-null int64
# Casualty Severity      1907 non-null int64
# Sex of Casualty        1907 non-null int64
# Age of Casualty        1907 non-null int64
# dtypes: int64(14), object(4)
# memory usage: 268.2+ KB

# %%
df_data_1.isnull().sum()
# Out:
# Reference Number       0
# Grid Ref: Easting      0
# Grid Ref: Northing     0
# Number of Vehicles     0
# Accident Date          0
# Time (24hr)            0
# 1st Road Class         0
# 1st Road Class & No    0
# Road Surface           0
# Lighting Conditions    0
# Weather Conditions     0
# Local Authority        0
# Vehicle Number         0
# Type of Vehicle        0
# Casualty Class         0
# Casualty Severity      0
# Sex of Casualty        0
# Age of Casualty        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_data_1.columns
# Out:
# Index(['Reference Number', 'Grid Ref: Easting', 'Grid Ref: Northing',
#        'Number of Vehicles', 'Accident Date', 'Time (24hr)', '1st Road Class',
#        '1st Road Class & No', 'Road Surface', 'Lighting Conditions',
#        'Weather Conditions', 'Local Authority', 'Vehicle Number',
#        'Type of Vehicle', 'Casualty Class', 'Casualty Severity',
#        'Sex of Casualty', 'Age of Casualty'],
#       dtype='object')

# %%
df_data_2=df_data_1[['1st Road Class', 'Road Surface', 'Lighting Conditions', 'Weather Conditions',
       'Casualty Class',  'Sex of Casualty', 'Age of Casualty', 'Number of Vehicles', 'Type of Vehicle', 'Casualty Severity']]

# %%
df_data_2.hist(figsize=(30,20))
plt.show()

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
df_data_2[['1st Road Class', 'Road Surface', 'Lighting Conditions', 'Weather Conditions',
       'Casualty Class',  'Sex of Casualty', 'Age of Casualty', 'Number of Vehicles', 'Type of Vehicle', 'Casualty Severity']].corr()['Casualty Severity'].sort_values(ascending=False)
# Out:
# Casualty Severity      1.000000
# Sex of Casualty        0.098581
# Number of Vehicles     0.098010
# Type of Vehicle        0.041183
# Weather Conditions    -0.012999
# Road Surface          -0.047385
# Lighting Conditions   -0.067238
# 1st Road Class        -0.067495
# Age of Casualty       -0.084154
# Casualty Class        -0.113017
# Name: Casualty Severity, dtype: float64

# %%
df_data_2['1st Road Class'].value_counts()
# Out:
# 6    1005
# 3     567
# 1     180
# 4      80
# 2      72
# 5       3
# Name: 1st Road Class, dtype: int64

# %%
df_data_2['Casualty Class'].value_counts()
# Out:
# 1    1152
# 2     428
# 3     327
# Name: Casualty Class, dtype: int64

# %%
df_data_2['Type of Vehicle'].value_counts()
# Out:
# 9     1295
# 1      236
# 3       77
# 19      73
# 11      65
# 8       60
# 5       39
# 4       17
# 2       16
# 21       8
# 20       6
# 10       4
# 22       3
# 97       3
# 16       2
# 90       2
# 17       1
# Name: Type of Vehicle, dtype: int64

# %%
df_data_2['Lighting Conditions'].value_counts()
# Out:
# 1    1389
# 4     436
# 6      43
# 7      30
# 5       9
# Name: Lighting Conditions, dtype: int64

# %%
df_data_2['Road Surface'].value_counts()
# Out:
# 1    1359
# 2     521
# 4      17
# 5       5
# 3       3
# 9       2
# Name: Road Surface, dtype: int64

# %%
df_data_2['Weather Conditions'].value_counts()
# Out:
# 1    1633
# 2     215
# 5      25
# 4      19
# 8       8
# 3       3
# 9       2
# 7       1
# 6       1
# Name: Weather Conditions, dtype: int64

# %%
df_data_2['Age of Casualty'].value_counts()
# Out:
# 27    66
# 30    54
# 20    54
# 26    53
# 29    50
# 24    48
# 25    48
# 22    47
# 32    46
# 21    45
# 19    43
# 23    43
# 28    42
# 35    39
# 39    38
# 40    38
# 34    36
# 38    35
# 18    35
# 33    34
# 31    34
# 36    33
# 45    31
# 41    31
# 51    31
# 43    29
# 44    29
# 17    29
# 37    28
# 46    27
#       ..
# 6     10
# 68     9
# 73     9
# 71     9
# 2      9
# 74     8
# 3      8
# 4      7
# 1      7
# 75     7
# 81     6
# 66     6
# 72     6
# 65     6
# 83     6
# 89     6
# 77     5
# 78     5
# 76     4
# 79     4
# 82     4
# 86     4
# 88     3
# 80     3
# 85     3
# 95     2
# 84     2
# 87     1
# 90     1
# 92     1
# Name: Age of Casualty, Length: 92, dtype: int64

# %%
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt

for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Lighting Conditions'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='yellow', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Lighting Conditions',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by lighting conditions' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Weather Conditions'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='orange', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Weather Conditions',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by weather conditions' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Road Surface'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='red', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Road Surface',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by road surface conditions' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Type of Vehicle'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='green', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Type of Vehicles',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by vehicle type' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['1st Road Class'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='blue', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('1st Road Class',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by road type' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Casualty Class'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='brown', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Casualty Class',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by casualty class' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Age of Casualty'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='bisque', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Age of Casualty',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by age of casualty' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Number of Vehicles'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='slategrey', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Number of Vehicles',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by vehicle number' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Sex of Casualty'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='lime', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Sex of Casualty',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by sex' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    
for s in np.arange(1):
    plt.subplots(figsize=(10,4))
    df_data_2.loc[df_data_2["Casualty Severity"] == s],df_data_2['Type of Vehicle'].value_counts().sort_values(ascending=False).head(20).plot.bar(width=0.5,color='rosybrown', edgecolor='k',align='center',linewidth=1)
    plt.xlabel('Type of Vehicle',fontsize=16)
    plt.ylabel('N° of car accidents',fontsize=16)
    plt.title('Number of accidents by vehicle type' ,fontsize=16)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)

# %%
ax = df_data_2.groupby(['Weather Conditions','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and Weather Conditions", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['Road Surface','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and Road Conditions", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['Lighting Conditions','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and Lighting Conditions", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['Type of Vehicle','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and Vehicle type", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['1st Road Class','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and road class", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['Number of Vehicles','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and vehicle number", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['Sex of Casualty','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and sex type of casualty", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
ax = df_data_2.groupby(['Casualty Class','Casualty Severity'])['Casualty Severity'].count().unstack(0).plot.bar(title="Number of Accidents by Casualty Severity and casualty class", figsize=(9,6))
_ = ax.set_xlabel('Casualty Severity Class')
_ = ax.set_ylabel('Number of accidents')

# %%
X=df_data_2[['Road Surface', 'Lighting Conditions', 'Weather Conditions',
        'Type of Vehicle','1st Road Class']].values #.astype(float)
X[0:5]
# Out:
# array([[ 1,  1,  1, 11,  3],
#        [ 1,  1,  1, 11,  3],
#        [ 1,  1,  1, 11,  3],
#        [ 1,  1,  1, 11,  3],
#        [ 1,  1,  1, 11,  3]])

# %%
y = df_data_2['Casualty Severity'].values
y[0:5]
# Out:
# array([3, 3, 3, 3, 3])

# %%
#Data Standardization give data zero mean and unit variance, it is good practice, especially for algorithms such as KNN which is based on distance of cases:

X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
X[0:5]
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-0.53283396, -0.58478514, -0.29651165,  0.45339929, -0.77661266],
#        [-0.53283396, -0.58478514, -0.29651165,  0.45339929, -0.77661266],
#        [-0.53283396, -0.58478514, -0.29651165,  0.45339929, -0.77661266],
#        [-0.53283396, -0.58478514, -0.29651165,  0.45339929, -0.77661266],
#        [-0.53283396, -0.58478514, -0.29651165,  0.45339929, -0.77661266]])

# %%
#Train/Test Split involves splitting the dataset into training and testing sets respectively, which are mutually exclusive. After which, you train with the training set and test with the testing set. 

#This will provide a more accurate evaluation on out-of-sample accuracy because the testing dataset is not part of the dataset that have been used to train the data. It is more realistic for real world problems.

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (1525, 5) (1525,)
# Test set: (382, 5) (382,)

# %%
#We will use a specific type of classification called K nearest neighbour.
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 4
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
neigh
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#            weights='uniform')

# %%
#Test Prediction
yhat = neigh.predict(X_test)
yhat[0:5]
# Out:
# array([3, 3, 3, 3, 3])

# %%
#ACCURACY EVALUATION
#In multilabel classification, __accuracy classification score__ is a function that computes subset accuracy. 
#This function is equal to the jaccard_similarity_score function. 
#Essentially, it calculates how closely the actual labels and predicted labels are matched in the test set.

from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.7809836065573771
# Test set Accuracy:  0.7513089005235603

# %%
#Lets change the K-number to k = 6
k = 6
neigh6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = neigh6.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat6))
# Out:
# Train set Accuracy:  0.8091803278688524
# Test set Accuracy:  0.7931937172774869

# %%
k = 8
neigh6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = neigh6.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat6))
# Out:
# Train set Accuracy:  0.8157377049180328
# Test set Accuracy:  0.7853403141361257

# %%
k = 9
neigh6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = neigh6.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat6))
# Out:
# Train set Accuracy:  0.8124590163934426
# Test set Accuracy:  0.7879581151832461

# %%
k = 12
neigh6 = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat6 = neigh6.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh6.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat6))
# Out:
# Train set Accuracy:  0.8137704918032787
# Test set Accuracy:  0.8089005235602095

# %%
Ks = 20
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.72251309, 0.68062827, 0.77225131, 0.7513089 , 0.78272251,
#        0.79319372, 0.79057592, 0.78534031, 0.78795812, 0.79842932,
#        0.80628272, 0.80890052, 0.81413613, 0.81413613, 0.80890052,
#        0.80890052, 0.79842932, 0.80628272, 0.80628272])

# %%
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.8141361256544503 with k= 13

# %%
car_accident_severity = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
car_accident_severity
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=12, p=2,
#            weights='uniform')

# %%
yhat = car_accident_severity.predict(X_test)
yhat[0:5]
# Out:
# array([3, 3, 3, 3, 3])

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, car_accident_severity.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.8137704918032787
# Test set Accuracy:  0.8089005235602095

# %%
from sklearn.metrics import classification_report

print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         3
#            2       0.67      0.13      0.22        75
#            3       0.81      0.98      0.89       304
#
#    micro avg       0.81      0.81      0.81       382
#    macro avg       0.49      0.37      0.37       382
# weighted avg       0.78      0.81      0.75       382
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.7528629354223725

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
md = 10
mean_acc = np.zeros((md-1))
std_acc = np.zeros((md-1))
ConfustionMx = [];
for n in range(1,md):
    
    #Train Model and Predict  
    loant = DecisionTreeClassifier(criterion="entropy", max_depth = n).fit(X_train,y_train)
    yhat=loant.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# array([0.79581152, 0.79581152, 0.79581152, 0.79581152, 0.79319372,
#        0.79057592, 0.79057592, 0.79842932, 0.80104712])

# %%
plt.plot(range(1,md),mean_acc,'r')
plt.fill_between(range(1,md),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Max Depth')
plt.tight_layout()
plt.show()

# %%
car_accident_severity = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
car_accident_severity
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Train the Decision tree model
car_accident_severity.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
yhat= car_accident_severity.predict(X_test)

# %%
print("Train set Accuracy: ", metrics.accuracy_score(y_train, car_accident_severity.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set Accuracy:  0.819672131147541
# Test set Accuracy:  0.7958115183246073

# %%
print (classification_report(y_test, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         3
#            2       0.00      0.00      0.00        75
#            3       0.80      1.00      0.89       304
#
#    micro avg       0.80      0.80      0.80       382
#    macro avg       0.27      0.33      0.30       382
# weighted avg       0.63      0.80      0.71       382
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...
